# %%
import tensorflow as tf
import keras
import pandas as pd
import sklearn

# %%
breeds = ["beagle" , "bernese_mountain_dog", "doberman" , "labrador_retriever" , "siberian_husky"]

# %% [markdown]
# Create a dictionnary that contains some of parameters of the function that we will read our images in.

# %%
args = {
    "labels" : "inferred",
    "label_mode": "categorical", #five breeds
    "batch_size": 32, #how many images loaded in precess at once
    "image_size": (256,256),
    "seed": 1,
    "validation_split": .2,
    "class_names": breeds
}

# %%
train = tf.keras.utils.image_dataset_from_directory(
    "images",
    subset = "training",
    **args
)
# Out:
# Found 926 files belonging to 5 classes.
# Using 741 files for training.

# %%
test = tf.keras.utils.image_dataset_from_directory(
    "images",
    subset = "validation",
    **args
)
# Out:
# Found 926 files belonging to 5 classes.
# Using 185 files for validation.

# %%
train
# Out:
# <BatchDataset element_spec=(TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 5), dtype=tf.float32, name=None))>

# %%
first = train.take(1)
first
# Out:
# <TakeDataset element_spec=(TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 5), dtype=tf.float32, name=None))>

# %%
images, labels = list(first)[0]

# %%
first_image = images[0]

# %%
first_image[:3, :3, 0]
# Out:
# <tf.Tensor: shape=(3, 3), dtype=float32, numpy=
# array([[17.658463, 25.686066, 29.847656],
#        [18.993622, 26.17189 , 29.454437],
#        [17.373474, 19.348282, 25.176407]], dtype=float32)>

# %%
from PIL import Image

Image.fromarray(first_image.numpy().astype("uint8"))
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x122D651E6A0>

# %%
labels[0]
# Out:
# <tf.Tensor: shape=(5,), dtype=float32, numpy=array([0., 0., 0., 1., 0.], dtype=float32)>

# %%
# train = train.prefetch(buffer_size=tf.data.experimental.AUTOtUNE)
# test = test.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
train = train.cache().prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
test = test.cache().prefetch(buffer_size=tf.data.experimental.AUTOTUNE)

# %%
from keras import layers
from keras.models import Sequential

model=Sequential([
    layers.Rescaling(1./255),
    layers.Conv2D(16, 3, padding="same", activation="relu", input_shape=(256,256,3) ),
    layers.Flatten(),
    layers.Dense(128, activation="relu"),
    layers.Dense(len(breeds))
])

# %%
model.compile(
    optimizer="adam",
    loss= tf.keras.losses.CategoricalCrossentropy(from_logits=True),
    metrics= ["accuracy"]
)

# %%
history= model.fit(train,
           validation_data=test,
           epochs=5,
           verbose=1
           )
# Out:
# Epoch 1/5
# 24/24 [==============================] - 42s 2s/step - loss: 35.6867 - accuracy: 0.2375 - val_loss: 4.8188 - val_accuracy: 0.2054
# Epoch 2/5
# 24/24 [==============================] - 32s 1s/step - loss: 1.9385 - accuracy: 0.4278 - val_loss: 1.6657 - val_accuracy: 0.3027
# Epoch 3/5
# 24/24 [==============================] - 31s 1s/step - loss: 1.0265 - accuracy: 0.6680 - val_loss: 1.5962 - val_accuracy: 0.3405
# Epoch 4/5
# 24/24 [==============================] - 32s 1s/step - loss: 0.6190 - accuracy: 0.8489 - val_loss: 1.6444 - val_accuracy: 0.3297
# Epoch 5/5
# 24/24 [==============================] - 32s 1s/step - loss: 0.2701 - accuracy: 0.9622 - val_loss: 1.8398 - val_accuracy: 0.3351

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_1 (Rescaling)     (None, 256, 256, 3)       0
#
#  conv2d (Conv2D)             (None, 256, 256, 16)      448
#
#  flatten (Flatten)           (None, 1048576)           0
#
#  dense (Dense)               (None, 128)               134217856
#
#  dense_1 (Dense)             (None, 5)                 645
#
# =================================================================
# Total params: 134,218,949
# Trainable params: 134,218,949
# Non-trainable params: 0
# _________________________________________________________________

# %%
import pandas as pd

history_df = pd.DataFrame.from_dict(history.history)
history_df[["accuracy", "val_accuracy"]].plot()

# %%
def train_model(network, epochs=5):
    model = Sequential(network)

    model.compile(optimizer='adam',
                  loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
                  metrics=['accuracy'])

    history = model.fit(
      train,
      validation_data=test,
      epochs=epochs
    )
    history_df = pd.DataFrame.from_dict(history.history)
    return history_df, model

# %%
network = [
  tf.keras.layers.Rescaling(1./255),
  layers.Conv2D(16, 4, padding='same', activation='relu', input_shape=(256,256,3)),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 4, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 4, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(len(breeds))
]

history_df, model = train_model(network)

# %%
history_df[["accuracy", "val_accuracy"]].plot()

# %%
data_augmentation = tf.keras.Sequential(
  [
    layers.RandomFlip("horizontal", seed=1),
      layers.RandomRotation(0.2, seed=1),
    layers.RandomZoom(0.2, seed=1),
  ]
)


full_network = [
    data_augmentation
] + network

history_df, model = train_model(full_network, epochs=10)

# %%
history_df[["accuracy", "val_accuracy"]].plot()

# %%
preds = model.predict(test)

# %%
import numpy as np
predicted_class = np.argmax(preds, axis=1)

# %%
actual_labels = np.concatenate([y for x, y in test], axis=0)

# %%
import itertools

actual_image = [x.numpy().astype("uint8") for x, y in test]
actual_image = list(itertools.chain.from_iterable(actual_image))
actual_image = [Image.fromarray(a) for a in actual_image]

# %%
actual_class = np.argmax(actual_labels, axis=1)

# %%
pred_df = pd.DataFrame(zip(predicted_class, actual_class, actual_image), columns=["prediction", "actual", "image"])

# %%
pred_df["prediction"] = pred_df["prediction"].apply(lambda x: breeds[x])
pred_df["actual"] = pred_df["actual"].apply(lambda x: breeds[x])
